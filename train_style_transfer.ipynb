# %%
from typing import List
import torch
from coop import VAE, util

from transformers import BertForMaskedLM, RobertaForMaskedLM, AutoTokenizer, AutoConfig, RobertaModel
from datasets import load_dataset

import torch
from torch.utils.data import Dataset, DataLoader
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.base has been moved to tensorflow.python.trackable.base. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.checkpoint_management has been moved to tensorflow.python.checkpoint.checkpoint_management. The old module will be deleted in version 2.9.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.resource has been moved to tensorflow.python.trackable.resource. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.util has been moved to tensorflow.python.checkpoint.checkpoint. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.base_delegate has been moved to tensorflow.python.trackable.base_delegate. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.graph_view has been moved to tensorflow.python.checkpoint.graph_view. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.python_state has been moved to tensorflow.python.trackable.python_state. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.saving.functional_saver has been moved to tensorflow.python.checkpoint.functional_saver. The old module will be deleted in version 2.11.
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.saving.checkpoint_options has been moved to tensorflow.python.checkpoint.checkpoint_options. The old module will be deleted in version 2.11.

# %%
from turtle import forward
import torch.nn as nn


class StyleTransferModel(torch.nn.Module):
    def __init__(self, latent_size: int, comp_size: int, emb_size: int, style_count: int) -> None:
        super().__init__()
        self.style_emb = nn.Embedding(style_count, emb_size)
        self.comp = nn.Linear(latent_size, comp_size)
        self.decomp = nn.Linear(comp_size + emb_size, latent_size)

    def forward(self, latent: torch.Tensor, style: torch.Tensor) -> torch.Tensor:
        x = self.comp(latent)
        e = self.style_emb(style.unsqueeze(1)).squeeze(1)
        x = torch.cat([x, e], dim=1)
        x = self.decomp(x)

        return x

# %%
from dataclasses import dataclass
from pprint import pprint
from typing import Dict
import numpy as np
from tqdm import tqdm
from collections import defaultdict


@dataclass
class Config:
    dataset_name: str = "yelp_polarity"

    vae_model_name: str = "megagonlabs/bimeanvae-yelp"  # or "megagonlabs/bimeanvae-amzn", "megagonlabs/optimus-yelp", "megagonlabs/optimus-amzn"
    latent_size: int = 512
    comp_size: int = 256
    emb_size: int = 512 - 256
    style_count: int = 2

    learning_rate: float = 1e-4
    batch_size: int = 32
    eval_batch_size: int = 4
    num_epochs: int = 500
    loss: str = "mse"
    device: str = "cuda:0"


def get_loss_fn(config):
    return nn.MSELoss()


def get_optimizer(params, config):
    return torch.optim.Adam(params, lr=config.learning_rate)


class Trainer:

    def __init__(self, config: Config) -> None:
        self.config = config
        self.train_dataset = load_dataset(config.dataset_name, split="train[:10%]")
        self.eval_dataset = load_dataset(config.dataset_name, split="test[:1%]")

        self.vae = VAE(config.vae_model_name).eval()
        self.style_transfer = StyleTransferModel(
            config.latent_size,
            config.comp_size,
            config.emb_size,
            config.style_count
        )

        self.loss = get_loss_fn(config)
        self.optim = get_optimizer(self.style_transfer.parameters(), config)

    def run(self):
        device = self.config.device
        self.vae.to(device)
        self.style_transfer.train().to(device)

        for e in range(self.config.num_epochs):
            self.run_train_epoch(e)
            self.evaluate()

    def run_train_epoch(self, epoch):
        self.optim.zero_grad()
        train_loader = DataLoader(self.train_dataset, self.config.eval_batch_size, shuffle=True)
        losses = []

        desc = tqdm(train_loader, desc=f"epoch {epoch}")
        for batch in desc:
            loss = self.train_step(batch)
            loss.backward()
            losses.append(loss.item())
            desc.desc = f"epoch {epoch}, loss={loss.item()}"

            self.optim.step()
            self.optim.zero_grad()

        print(np.mean(losses))

    def train_step(self, batch: Dict):
        device = self.config.device
        texts = batch["text"]
        labels = batch["label"].to(device)

        with torch.no_grad():
            latent = self.vae.encode(texts)
        latent_pred = self.style_transfer(latent, labels)

        loss = self.loss(latent, latent_pred)

        return loss

    @torch.no_grad()
    def evaluate(self):
        train_loader = DataLoader(self.eval_dataset, self.config.batch_size)
        losses = []
        result = defaultdict(list)

        for batch in tqdm(train_loader, desc=f"Evaluating..."):
            step_out = self.eval_step(batch)
            
            losses.append(step_out.pop("loss"))
            for k, v in step_out.items():
                result[k] += v

            # 넘 많아..
            break

        result["loss"] = np.mean(losses)
        pprint(result)

    def eval_step(self, batch: Dict) -> Dict:
        device = self.config.device
        texts = batch["text"]
        labels = batch["label"].to(device)

        latent = self.vae.encode(texts)
        latent_pred = self.style_transfer(latent, labels)
        latent_pred_neg = self.style_transfer(latent, 1 - labels)
        loss = self.loss(latent, latent_pred)

        preds = self.vae.generate(latent_pred)
        preds_neg = self.vae.generate(latent_pred_neg)

        return {
            "loss": loss.item(),
            "text": texts,
            "prediction": preds,
            "negative_prediction": preds_neg
        }

# %%
config = Config()
trainer = Trainer(config)
# Out:
# Reusing dataset yelp_polarity (C:\Users\heegyukim\.cache\huggingface\datasets\yelp_polarity\plain_text\1.0.0\a770787b2526bdcbfc29ac2d9beb8e820fbc15a03afd3ebc4fb9d8529de57544)
# Reusing dataset yelp_polarity (C:\Users\heegyukim\.cache\huggingface\datasets\yelp_polarity\plain_text\1.0.0\a770787b2526bdcbfc29ac2d9beb8e820fbc15a03afd3ebc4fb9d8529de57544)
# d:\Anaconda3\lib\site-packages\huggingface_hub\file_download.py:560: FutureWarning: `cached_download` is the legacy way to download files from the HF hub, please consider upgrading to `hf_hub_download`
#   warnings.warn(

# %%
try:
    trainer.run()
except KeyboardInterrupt:
    pass
# Out:
# epoch 0, loss=0.007826965302228928: 100%|██████████| 14000/14000 [02:26<00:00, 95.41it/s]
# 0.038999862750010966
# Evaluating...:   0%|          | 0/12 [00:00<?, ?it/s]
# defaultdict(<class 'list'>,
#             {'loss': 0.008132265880703926,
#              'negative_prediction': ['5 stars for the service, I have been '
#                                      'here about 3 times now. I have been here '
#                                      'about 5 times and have always been '
#                                      'satisfied with the service. The food is '
#                                      'always good, and the prices are '
#                                      "reasonable. I don't know what they are "
#                                      "doing, but it's just not my thing. I "
#                                      'have been here several times and have '
#                                      'never had a bad experience. The staff is '
#                                      'always friendly, and the food is always '
#                                      'good. My only complaint is that they '
#                                      "don't have a lot of people on the menu. "
#                                      "Other than that, it's a great place to "
#                                      'bring your friends.',
#                                      'Last week I had to get a new tire to get '
#                                      "in and out of this place. I've been "
#                                      'going to this place for a long time and '
#                                      "I'm so glad I did. They have a great "
#                                      'selection of beers, and the staff is '
#                                      "super friendly. The only thing I didn't "
#                                      "like about this place is that they don't "
#                                      'seem to care about their customers. So, '
#                                      "I'm sorry to say I will be going back to "
#                                      'this place.',
#                                      'Friendly staff, fair pricing, good '
#                                      'service. Sometimes you can get the same '
#                                      'thing.',
#                                      'The food is good, but the service is hit '
#                                      'or miss. The waitresses are very '
#                                      'attentive and the waiters are very '
#                                      'friendly. The food is always good and '
#                                      'the prices are pretty reasonable for the '
#                                      "quality of the food. It's a great place "
#                                      'to avoid the long wait times.',
#                                      "Even though I didn't have a lot of time "
#                                      'to spend the night here I was not sure '
#                                      "what to expect. I'm not sure what the "
#                                      "heck of the store is, but it's still a "
#                                      'great place to stop and get some work '
#                                      "done. I've been here several times and "
#                                      "it's always consistently good. The only "
#                                      'thing I can say about this place is that '
#                                      "it's a little pricey for what you get, "
#                                      "but it's worth it. I'm not sure if I'll "
#                                      "be going back, but I'm sure it's better "
#                                      "than the other ones I've been to.",
#                                      "If you're looking for a fun night out, "
#                                      'this is the place to go. The food is '
#                                      "so-so, but it's more of a bar than a "
#                                      "bar. If you're in the mood for a drink, "
#                                      "you'll have to wait for a table. It's a "
#                                      'great place to hang out and have a '
#                                      "drink. The only thing that I didn't like "
#                                      "about this place is that it's a little "
#                                      "bit of a dive bar, but it's worth the "
#                                      "wait. I'm not sure if it's anything "
#                                      "special, but it's worth the trip. I'm "
#                                      "not a fan of the bar scene, but it's a "
#                                      'great place to hang out with friends. '
#                                      'They have a good selection of beers on '
#                                      'tap, and the bartenders are really nice. '
#                                      "If you're in the area, go here!",
#                                      'Mediocre food. Great service. The food '
#                                      'was great. Our waitress was fast and '
#                                      'friendly. The manager was very nice and '
#                                      'patient. We had a great time at the bar. '
#                                      'Great atmosphere.',
#                                      "Ok, I love this place! I've been here a "
#                                      'couple of times and have had a great '
#                                      'experience. I went for the first time '
#                                      'last night and it was a great '
#                                      'experience. The bar area was clean, and '
#                                      'the staff was very friendly. I had the '
#                                      'veggie burger and it was really good. I '
#                                      'asked for a little bit of cheese, and it '
#                                      "was so good that I couldn't eat it. I "
#                                      'asked for a side of fries and it was '
#                                      "just ok. I'm not a big fan of cheese "
#                                      "curds, but I'm not sure what to expect. "
#                                      'I ordered a side of fries and it was '
#                                      "really good. The only thing I didn't "
#                                      'care for was the horseradish sauce. I '
#                                      "just couldn't even eat it. I asked for a "
#                                      'side of fries, and then proceeded to ask '
#                                      'for it. I asked for a side of fries and '
#                                      "she said it was the best one I've had in "
#                                      'a long time. So I decided to give it a '
#                                      "try. I'm not sure if I'll be back, but I "
#                                      'will definitely be back. I really '
#                                      'enjoyed the food and the service. I '
#                                      "can't say enough good things about this "
#                                      'place. I really liked the atmosphere and '
#                                      'the staff. I will be back.',
#                                      "I used to love this place, but it's not "
#                                      'as good as it used to be. The staff is '
#                                      'friendly and the food is so good. The '
#                                      "only reason I didn't give it 5 stars is "
#                                      'the fact that they have games in the bar '
#                                      'area where you can play games and play '
#                                      "games. It's a nice place to hang out "
#                                      'with friends and have a conversation '
#                                      'with your friends. The food is good and '
#                                      'the prices are very reasonable. I would '
#                                      'recommend this place to anyone who wants '
#                                      "to get some good food and drink. It's a "
#                                      "bit pricey for what you get, but it's "
#                                      'worth it!',
#                                      "Like a Barnes and Noble, but it's a nice "
#                                      'place to go. The staff is very friendly '
#                                      'and helpful. They have a large selection '
#                                      'of products, and the prices are pretty '
#                                      "decent. However, it's hard to find a "
#                                      'good selection of items. They are all '
#                                      'very nice and helpful.',
#                                      'Meh. I had the veggie burger, and it '
#                                      "was\\\\\\n\\n\\n't seasoned. I asked for "
#                                      'a side of fries, and it was "sweet '
#                                      'potato fries". I asked for a side of '
#                                      'cole slaw, which came with a side of '
#                                      'cole slaw. The waitress was nice and '
#                                      'attentive. My only complaint is that '
#                                      "it's a bit pricey for what you get, but "
#                                      "it's worth it. The only thing I didn't "
#                                      'like was that the waitress was very nice '
#                                      "and attentive. I'm not sure if I'll be "
#                                      "back, but I'll be back.",
#                                      "Unexpected, but I don't think I've ever "
#                                      "been to this restaurant in years. I've "
#                                      'only been here in the past three years, '
#                                      'and I have to say that the food is '
#                                      'really good. The only thing that makes '
#                                      "it better is the service. I've been here "
#                                      "a handful of times and I've never had a "
#                                      'bad experience. My only gripe is that '
#                                      'the food is so damn good. I have tried '
#                                      "other items on the menu, and I can't "
#                                      "remember the name of the restaurant. I'm "
#                                      'not sure why people are complaining '
#                                      "about this place, but it's so worth it!",
#                                      "3.5 stars for the food. It's not as good "
#                                      "as it used to be, but it's worth the "
#                                      'wait. My only complaint is that they '
#                                      "only have a few tables, so it's nice to "
#                                      'sit at the bar. I had the veggie burger '
#                                      'and it was really good. I had the veggie '
#                                      'burger and it was delicious. My husband '
#                                      'had the wild mushroom burger. Both were '
#                                      'very good. I had the grilled cheese and '
#                                      'it was so good. The only thing that I '
#                                      "didn't like was the fact that they were "
#                                      'a little on the dry side, but I thought '
#                                      "it was just ok. I'm not sure if I will "
#                                      'be back, but I will continue to come '
#                                      'back.',
#                                      'Our server was very friendly, the food '
#                                      'came out quickly, and the service was '
#                                      'fast. We sat at the bar and it was one '
#                                      'of the most comfortable dining '
#                                      'experiences I have ever had. The food '
#                                      'was delicious, the atmosphere was nice, '
#                                      'and the environment was very inviting. '
#                                      'We had a good time, and we were able to '
#                                      'get our food quickly. The staff was very '
#                                      'attentive and attentive. I would '
#                                      'definitely recommend this place for '
#                                      "lunch or dinner. It's always busy, but "
#                                      "it's worth the wait.",
#                                      'Good quality Chinese food. Good service '
#                                      'and fast service. Spicy chicken was cold '
#                                      'and had a nice amount of beef. Not bad. '
#                                      'Will be back to try other dishes.',
#                                      'Very bad experience. I bought a purchase '
#                                      'with a shirt. I asked for a quote, but '
#                                      'they still charged me. I will never go '
#                                      'back to this shop again. The people at '
#                                      'the front are rude.',
#                                      "I love this place! I think I've had a "
#                                      "lot of bad experiences but I think it's "
#                                      "the best in the area. I've been here a "
#                                      "couple of times and both times I've had "
#                                      'a great experience. The only reason I '
#                                      "didn't give it 5 stars is because of the "
#                                      'fact that they have a nice patio area '
#                                      "for people watching. I'm not sure if "
#                                      'they are doing anything about it. I '
#                                      "don't think I've ever had a bad "
#                                      'experience here. I have been here '
#                                      'several times and I have never had a bad '
#                                      "experience. The only reason I didn't "
#                                      'give them 5 stars is because the service '
#                                      "is pretty good. I can't say enough good "
#                                      "things about this place. I've been here "
#                                      "a few times and I've never had a bad "
#                                      'experience. I have been here several '
#                                      "times and I've never had a problem with "
#                                      'any of the other locations. I would '
#                                      'recommend this place to anyone looking '
#                                      'for a nice local spot to get a quick '
#                                      "bite to eat. I'm not a huge fan of the "
#                                      'beer selection but I have to say that '
#                                      "I'm not much of a fan of this place. So, "
#                                      "I can't say enough good things about "
#                                      'this place.',
#                                      'My favorite place to come out to have a '
#                                      "great burger. I come here every time I'm "
#                                      'in the area. The last time I was there I '
#                                      "ordered the chicken nuggets. I'm not a "
#                                      'huge fan of the chicken. This is the '
#                                      "best burger I've ever had. I also love "
#                                      'that they have a lot of vegetarian '
#                                      'options. This is my second time coming '
#                                      'here.',
#                                      'Wow. What a disappointment. I just moved '
#                                      'to the area and was looking for a place '
#                                      "to eat. I'm glad I found this place. "
#                                      "I've been to a few different places in "
#                                      "the area and this one is the best. I've "
#                                      'been here a couple of times and have '
#                                      'never been disappointed. The food is '
#                                      "always fresh and delicious. I've never "
#                                      'had a bad meal here. I love the fact '
#                                      'that they have the best fried chicken in '
#                                      "the city. I've never had a bad meal "
#                                      "here. The service is always great. I've "
#                                      'been coming here for years and have '
#                                      "never had a bad experience. I'll be "
#                                      'back.',
#                                      'I love this place! My husband and I have '
#                                      'been coming to this place for the past '
#                                      "year and wen'n't go to any other "
#                                      "restaurant. I've never had a bad meal at "
#                                      'this place. My only complaint is that '
#                                      "it's hard to get a table for 10 people. "
#                                      "I always get the cole slaw and it's just "
#                                      "ok. I don't really care for the "
#                                      'plantains, but if you want a yummy meal, '
#                                      'this is the place to go!',
#                                      'This is probably my favorite place in '
#                                      "the area. I've been here a handful of "
#                                      'times now, and I have yet to be '
#                                      'disappointed. The staff is always '
#                                      'friendly and the place is always clean. '
#                                      "The only thing I don't like about this "
#                                      "place is that they don't have a large "
#                                      "selection of food, but it's not the best "
#                                      "I've ever had. It's a little smaller "
#                                      "than I expected, but I'm sure it's worth "
#                                      "the wait. It's a bit of a drive for me, "
#                                      "but it's always worth the wait. I can't "
#                                      'say enough good things about this place, '
#                                      'and the service is always great. On the '
#                                      'other hand, the staff is very friendly '
#                                      "and accommodating. I've been here "
#                                      'several times and have never been '
#                                      'disappointed.',
#                                      "This is my go-to place to go. I've been "
#                                      "coming here for years and it's always a "
#                                      'great experience. They have some of the '
#                                      "best deals I've ever had. I don't think "
#                                      "I've ever had a bad experience here. The "
#                                      'employees are all very nice and helpful. '
#                                      'I have been here several times and have '
#                                      'never been disappointed. The store is '
#                                      'very clean and the workers are always so '
#                                      'nice. They have a good selection of all '
#                                      "the products I've had here. I will be "
#                                      'back.',
#                                      "Love this place. They're always willing "
#                                      'to help. The workers are always so nice '
#                                      "and helpful. I've never seen a bad one.",
#                                      'Went here with a group of friends for '
#                                      'dinner. The restaurant was a bit loud '
#                                      "but we couldn't get enough of the "
#                                      'restaurant. The waitress was very '
#                                      'attentive and attentive. We had the '
#                                      '"nodnn" which was really good. My '
#                                      'husband had the lamb chops and she liked '
#                                      'it. I ordered the lamb schnitzel and it '
#                                      'was delicious. My husband had the veggie '
#                                      'burger and she enjoyed it. I had the '
#                                      'grilled cheese and it was really good. '
#                                      "The only thing I didn't care for was the "
#                                      "horseradish sauce. I couldn't even "
#                                      'finish it. I asked for a little bit of '
#                                      'salt and pepper. I asked for a little '
#                                      'bit more salt and pepper, but it was '
#                                      "just ok. I can't say enough good things "
#                                      'about this place. I will definitely be '
#                                      'back.',
#                                      'I love this place! The cut is awesome! I '
#                                      'have been going there for years. They '
#                                      'are so nice and friendly! I love my hair '
#                                      'cut!',
#                                      "As a college student, I've been here a "
#                                      'couple of times now, and I have to say, '
#                                      "I'm not sure if it's the best Chinese "
#                                      "food I've had in a long time. The only "
#                                      'thing I liked about this place is that '
#                                      "it's a bit of a drive for me, but I'm "
#                                      "not sure if it's worth the wait. I've "
#                                      'been here several times and have never '
#                                      'had a bad experience. The food is '
#                                      'consistently good, and the service is '
#                                      "pretty good. The only reason I didn't "
#                                      'give it 5 stars is because the food is '
#                                      "really good. I'm not a big fan of the "
#                                      "spicy tuna roll, but I've had better. "
#                                      "I'm not a big fan of Thai food, but it's "
#                                      "worth it. The only thing I don't like "
#                                      'about this place is that the restaurant '
#                                      'is very clean and well-stocked. Service '
#                                      'is a bit slow, but the food is '
#                                      "consistently good. I'm not a fan of the "
#                                      "spicy tuna roll, so I'm not sure if it's "
#                                      "better, but it's pretty good. I'd "
#                                      'recommend this place for a quick bite to '
#                                      'eat.',
#                                      'This place is sooo good. The staff is '
#                                      'friendly and welcoming, and the people '
#                                      "are very friendly. The only reason I'm "
#                                      'not giving them five stars is because '
#                                      "they don't seem to know what they are "
#                                      "doing, but I'm not sure if it's as good "
#                                      "as it gets. The only reason I'm giving 4 "
#                                      "stars is that they don't care about "
#                                      'their customers. They have a great '
#                                      'selection of beers, and the prices are '
#                                      'reasonable for the quality of the food.',
#                                      "I've been going to this nail salon since "
#                                      'I was in the area and decided to give it '
#                                      "a try. I've been to many of the other "
#                                      'nail salons in the area and I have to '
#                                      'say that I am very pleased with the '
#                                      'results. The staff is very friendly and '
#                                      'helpful. They have a great bedside '
#                                      "manner. The only thing that I didn't "
#                                      "like about this place is that it's a "
#                                      'little difficult to get in and out, but '
#                                      'if you want to get your nails done, you '
#                                      "will not be sorry. I've been going to "
#                                      'this salon for about a year now and I '
#                                      "can't wait to go back and try more of "
#                                      'their products.',
#                                      "Yes, it's a good place to eat. The only "
#                                      "reason I didn't give this place 5 stars "
#                                      'is because the food and service was '
#                                      'awful.',
#                                      'The people who work here are very nice. '
#                                      'I have been here a few times, and the '
#                                      'staff is always friendly. The person '
#                                      'working there is very nice and helpful. '
#                                      "It's a great place to go if you are "
#                                      'looking for a good place to catch up '
#                                      'with friends. I am not a big fan of the '
#                                      'person behind the bar. It is a great '
#                                      "place to get some work done. It's not "
#                                      "the best, but it's just a good place to "
#                                      'go. I am not sure if I will be back.',
#                                      "I've been here a few times, and I've "
#                                      'always had a great time. I have to say, '
#                                      "it's a nice place to go for lunch or "
#                                      'dinner. The service is always good, and '
#                                      'the food is always good. My only '
#                                      "complaint is that it's hard to get a "
#                                      'table in the bar area. I usually get the '
#                                      "veggie burger, but I've never had a bad "
#                                      "meal. It's hard to find something that "
#                                      "isn't good, but I've never had a bad "
#                                      "experience. I've never had a bad meal "
#                                      "here, and I've never had a bad "
#                                      "experience. The only thing I don't like "
#                                      'about this place is that they are always '
#                                      'busy.',
#                                      'The service was good and the food was '
#                                      'good. I had the shrimp and crab Rangoon. '
#                                      'They were all delicious. I had the '
#                                      'shrimp and crab Rangoon which was very '
#                                      "good. I didn't care for the sauce but it "
#                                      'was a little too salty for me. I would '
#                                      "give it another try. You won't be "
#                                      'disappointed.'],
#              'prediction': ['5 stars for the service, I have been here about 3 '
#                             'times now. I have been here for about 5 years and '
#                             'have never had a bad experience. The staff is '
#                             'always friendly, and the food is consistently '
#                             "good. I don't know what they're doing, but it's "
#                             'just not my thing. I have been here several times '
#                             'and have always been pleased with the service, '
#                             "and the quality of the food. It's a great place "
#                             'to bring your friends and family. The prices are '
#                             'reasonable and the food is good.',
#                             'Last week I had to get a new tire to get in and '
#                             'out of this place. I had to wait a little longer '
#                             'than I had to get in. I called and asked for a '
#                             "new tire, and they told me it's going to be 20 "
#                             "minutes. They didn't seem to care about the "
#                             "problem. I've been going there for over a year "
#                             "now, and I've never had a problem with the "
#                             'service. They are very fast and friendly.',
#                             'Friendly staff, fair pricing, good service. '
#                             'Sometimes you can get the same thing.',
#                             'The food is good, but the service is hit or miss. '
#                             'The waitresses are very attentive and the waiters '
#                             "are very friendly. The only reason I didn't give "
#                             'them 4 stars is because the food is pretty good '
#                             'and the prices are very reasonable.',
#                             "Even though I didn't have a lot of time to spend "
#                             "the night here I was not sure what to expect. I'm "
#                             'not sure how this place has a better selection of '
#                             "stores, but it's just not the same. I've been to "
#                             "this location several times and it's always "
#                             'consistently good. The only thing I can say about '
#                             "this place is that it's a little pricey for what "
#                             "you get. I've been here twice and I've never had "
#                             "a bad experience. I'm not sure if it's better, "
#                             "but it's still really good. I'll be coming back "
#                             'to try more things on the menu.',
#                             "If you're looking for a fun night out, this is "
#                             "the place to be. The food is great, but it's not "
#                             "so good. If you're looking for a place to get a "
#                             "table, then you'll want to go somewhere else. "
#                             "It's a great place to hang out with friends and "
#                             "family. The only thing that I didn't like about "
#                             "this place is that it's open 24 hours, so it's "
#                             "worth the wait. I'm not a big fan of the bar "
#                             "scene, but it's a great place to hang out with "
#                             'friends. They have a good selection of beers, and '
#                             "they have a good selection of beers. If you're in "
#                             "the area, you'll want to come here.",
#                             'Horrible service. Mediocre food. The food was '
#                             'great but the service was terrible. Our waitress '
#                             'was very slow. No manager at all. Long wait '
#                             'times. Bad food. Avoid.',
#                             "Ok, I love this place! I've been here a couple of "
#                             'times and have had a great experience. I went for '
#                             'the first time last night and it was a great '
#                             'experience. The bar area was clean, and the staff '
#                             'was very friendly. The only thing that stood out '
#                             'to me was the bar area. It was a little loud, but '
#                             'it was a little difficult to get a table. I asked '
#                             'for a beer and a drink, and the bartender was '
#                             "very nice and attentive. I'm not sure if it was "
#                             'one of the bartenders, but she was very nice and '
#                             'attentive. I really enjoyed the food and the '
#                             'atmosphere. I will definitely be coming back. I '
#                             "had the veggie burger and it was really good. I'm "
#                             'not a big fan of cheese curds, so I decided to '
#                             "give it a try. I'm not sure if I'll be going "
#                             'back, but I will definitely be back.',
#                             "I used to love this place, but it's not the best "
#                             'place to go in the area. It has a lot of games '
#                             "and games to play with. The only reason I didn't "
#                             'give it 5 stars is because the food is so so, '
#                             "it's not as good as it gets. It's a little pricey "
#                             'for what you get, but the food is really good. '
#                             'The staff is very friendly and accommodating. '
#                             'They have a large selection of games to choose '
#                             'from and the games are great. I would recommend '
#                             'this place to anyone who wants to hang out with '
#                             'friends and have a good time!',
#                             "Like any other Barnes and Noble, it's a great "
#                             'place to visit. The staff is very friendly and '
#                             'helpful. They have a large selection of books, '
#                             "and it's hard to find a good selection. However, "
#                             "it's pretty expensive for what you get. They are "
#                             'all very nice and helpful.',
#                             'Meh. I had the veggie burger, and it '
#                             "was\\\\\\n\\n\\n't seasoned. I asked for a side "
#                             'of fries, and it came with a side of cole slaw. '
#                             'The waitress was nice and attentive. My only '
#                             "complaint is that it's hard to get a table to sit "
#                             'at the bar. The waitress was very nice and '
#                             'attentive. I had the veggie burger, which was '
#                             "good, but I'm not a fan of the fries. I'm not "
#                             'sure what else to say, but it was really good. '
#                             "The only thing I didn't like was that it was a "
#                             'little on the salty side. My husband had the '
#                             "steak and eggs, and she said it was the best I've "
#                             'ever had. I will definitely be returning.',
#                             "Unexpected, kind, and friendly staff. I've been "
#                             "here three times in the past few months and I've "
#                             "only had one bad experience. I've been to this "
#                             'restaurant several times and have never been '
#                             'disappointed. The only thing I can say about this '
#                             'place is that the food is consistently good and '
#                             'the service is always good. I have been here '
#                             "twice and I've never had a bad experience. The "
#                             'only thing that I really liked about this place '
#                             "is the service. I'm not sure why people are "
#                             "complaining about the food, so I can't wait to go "
#                             'back and try other items on the menu.',
#                             "3.5 stars for the food. It's not as good as it "
#                             "used to be, but it's worth the wait. My only "
#                             'complaint is that they only have a few tables, so '
#                             "it's hard to find a place to sit at the bar. The "
#                             'waitress was very nice and helpful. I had the '
#                             'veggie burger and it was really good. I had the '
#                             'veggie burger and it was delicious. My husband '
#                             'had the fried chicken sandwich. Both were very '
#                             'good. I thought the salad was a little bland, but '
#                             "it was just ok. I'm not sure if it was one of the "
#                             "best ones I've had, but I'm not a big fan of the "
#                             'rest of the food. I will definitely be back.',
#                             'Our server was very nice, the food was really '
#                             "good, but it wasn't anything to write home about. "
#                             'We had one of the most delicious salads that I '
#                             'have ever had. The fries were good, the onion '
#                             'rings were good, and the fries were so flavorful. '
#                             'The only thing I would say is that they are not '
#                             "busy at all, but it's definitely worth the wait. "
#                             "I've been here a few times now and have always "
#                             'been pleased with the service and the food. I '
#                             'recommend sitting at the bar if you want to get a '
#                             'table for more than 15 people.',
#                             'Good quality Chinese food. Good service and fast '
#                             'service. The chicken was cooked perfectly and had '
#                             'a nice amount of sauce. Spicy beef was delicious. '
#                             'Not too bad. Will be back!',
#                             'Very bad experience. I bought a purchase with a '
#                             "shirt. I asked for a quote, but they still didn't "
#                             'care. I am so disappointed. I will never return '
#                             'to this shop.',
#                             "I think I'm a big fan of this place! I think it's "
#                             "a bit of a drive for me but I don't think I've "
#                             "ever had a bad experience. I've been here a "
#                             "couple of times and I've never had a bad "
#                             "experience. The only reason I didn't give it 5 "
#                             'stars is because the food is just ok. On the '
#                             'other hand, the service is great. I have been '
#                             "here several times and I've never had a bad "
#                             "experience. The only thing that I didn't like "
#                             "about this place is that it's a little pricey for "
#                             'what you get. I would give them 10 stars if I '
#                             "could. I have been there several times and I'm "
#                             'not a huge fan of the rest of the food. But I '
#                             "can't say enough good things about this place. "
#                             "I'm not a huge fan of the food, but I can't wait "
#                             'to go back and try some of the other items on the '
#                             'menu.',
#                             'My first time coming here. I ordered the chicken '
#                             'nuggets and my friend ordered the chicken salad. '
#                             'The chicken was under cooked. The last time I was '
#                             'there I had to come back the next day. This is '
#                             "the second time I've ever been to this location. "
#                             "I'm a huge fan of this place. I'm going to come "
#                             'back.',
#                             'Wow. What a disappointment. We just moved to the '
#                             'area and needed a place to eat. My husband and I '
#                             'went there for the first time. We were a little '
#                             "disappointed. The food was just ok. I'm not a "
#                             "huge fan of the food, but this was the worst I've "
#                             "ever had. I've been to a lot of other restaurants "
#                             "in the area and this one is the worst. I've never "
#                             "had a bad experience here. I'm not sure if it's "
#                             "that good, but I guess that's how they make the "
#                             'food. I have never had a bad experience here. '
#                             "I'll be coming back for more.",
#                             "I fell in love with this place and I'm glad we "
#                             'did! My husband and I tried the veggie pizza and '
#                             'the buffalo chicken sandwich. We both had the '
#                             'macnn cheese and cole slaw which was very tasty. '
#                             'My hubby had the Mac and cheese and it was '
#                             "delish! I couldn't get enough of that. The only "
#                             "thing I didn't like about this place is that it's "
#                             'hard to get a table for 10 people. I will '
#                             'definitely be going back!',
#                             'This is probably my favorite place in the area. '
#                             "I've been here a handful of times now, and I've "
#                             'always had a great experience. The staff is '
#                             'always friendly, and the place is always clean. '
#                             "It's a bit of a drive-through, but it's well "
#                             "worth the wait. The only thing I don't like about "
#                             "this place is that it's always busy, and the "
#                             'service is quick and friendly. On the other hand, '
#                             "the food is very good. I'm a big fan of their "
#                             "fried chicken, and I have to say, it's the best "
#                             "I've ever had. I can't wait to go back!",
#                             "This is my go-to place. I've been coming here for "
#                             "a long time and I have to say it's always been a "
#                             "great experience. I've been here several times "
#                             "and haven't had any problems with any of the "
#                             'other locations. They have a great selection of '
#                             "local produce. The only thing I don't like is "
#                             'that they have a decent selection of beer and '
#                             "wine. I've been here several times and have never "
#                             'been disappointed. The service is always good and '
#                             'the prices are very reasonable. I will be back.',
#                             "Love this place. They're always willing to help. "
#                             "The workers are always so nice and helpful. I've "
#                             'been looking for a good one by far.',
#                             'Went here with a group of friends for dinner. The '
#                             "restaurant was a bit loud but we couldn't get "
#                             'enough of the restaurant. The waitress was very '
#                             'attentive and attentive. We had the "nachos" '
#                             'which was really good. My husband had the lamb '
#                             'chops and she liked it. I ordered the veggie '
#                             'burger and it was really good. My only complaint '
#                             "was that the waitress couldn't care more about "
#                             'his meal. I asked for a little bit of salt and '
#                             "pepper and she didn't even touch it. I asked for "
#                             'a little bit of salt and pepper, and she said it '
#                             "wasn't what I expected. Overall, the food was ok, "
#                             "but not worth the price. I can't say enough good "
#                             'things about this restaurant. I will definitely '
#                             'be back.',
#                             'I love this place! The cut is awesome! I have '
#                             'been going there for years. They are so nice and '
#                             'friendly! I love my hair cut!',
#                             "I love this place! I've been here a couple of "
#                             "times now and I've had a lot of fun with my "
#                             'family. The food is consistently good. The only '
#                             "thing I don't like about this place is that it's "
#                             "hard to find a good place to eat. I'm not sure if "
#                             "it's worth the wait, but it's worth it. I'm not a "
#                             "big fan of Chinese food, but I've had better. "
#                             "I've been here several times and have never had a "
#                             "bad experience. The only thing I didn't like "
#                             'about this restaurant is that the food is pretty '
#                             "good. I'm not a big fan of the food, but the "
#                             "service is pretty good. The only reason I didn't "
#                             'give it 5 stars is because the food is really '
# ...
#                       'got the peach cobbler hard ice cream and that was to '
#                       'die for! We got 4 servings of ice cream for $10, which '
#                       "nowadays is a steal IMO! :) \\n\\nI'll definitely be "
#                       'heading back with my coworkers this week!',
#                       'This is by far, the BEST soft serve ice cream place in '
#                       'southwestern PA. The \\""flavor of the week\\"" is '
#                       'always interesting-and tasty! Though, I am somewhat '
#                       "disappointed that they've switched to a lower grade ice "
#                       'milk, for their vanilla and chocolate offerings. I '
#                       "don't know if this is a matter of cutting corners, or "
#                       "if the better stuff simply isn't available any longer. "
#                       'Either way, this place is still leaps and bounds ahead '
#                       "of DQ, Tastee Freeze, etc. It's definitely worth the "
#                       "trip. It's mostly street parking, though they do have "
#                       'about 3-4 parking spaces off to the side. Serving sizes '
#                       'are huge! The small cone here, is the same size as a DQ '
#                       "large. And the large is SO big, they can't fit it "
#                       'through the window-they hand it out the side '
#                       'door.\\n\\nIf you want a real \\""Kodak '
#                       'moment\\""-order a large cone for the kids, and keep '
#                       'the camera, and wet wipes handy!',
#                       'This is my go-to distributer. They have a great '
#                       "selection and lots of hard to find brews. I haven't "
#                       "noticed that it's any more expensive than going "
#                       "elsewhere but honestly if I don't buy here then I'm "
#                       'buying six packs which as we all know are a huuugggge '
#                       'rip off. So any time I have a case of something I love '
#                       "I feel like I'm getting a bargain. The cold selection "
#                       'does suck so I try to plan ahead and have what I need '
#                       'already cold. Staff here are all very helpful- and will '
#                       'have recommendations if you ask.',
#                       "Love this beer distributor.  They always have what I'm "
#                       'looking for. The workers are extremely nice and always '
#                       "willing to help. Best one I've seen by far.",
#                       'Went here with a gift card from the restaurant week '
#                       'photo competition. \\n\\nWe were one of two tables '
#                       'there and a bunch of staff showing up during the meal. '
#                       "\\n\\nOur waitress was good, but that couldn't save the "
#                       'food.\\n\\nThe meal started out with some what I guess '
#                       'used to be foccacia.  I say used to be because it no '
#                       'longer represented anything other than long pieces of '
#                       'brick or bark very stale and tasteless.\\n\\nWe ordered '
#                       'the vegetable board which was probably the best thing '
#                       'we ordered with light and bright vegetables perfectly '
#                       'cooked and paired with two delicious sauces. \\n\\nThen '
#                       'we ordered the octopus which was fine, but very cold '
#                       'and the octopus had little to no flavor, being '
#                       'overwhelmed by the citrus in the dish. \\n\\nThe tuscan '
#                       'wings were ok, but they were really ordered for my '
#                       'husband who seemed to enjoy them. \\n\\nFinally the '
#                       'diver scallops.  This dish was indeible.  The scallops '
#                       'were very overcooked and the pea puree was so minty I '
#                       'was unable to eat it. We sent it back and they did take '
#                       "off half of the price (weren't expecting anything just "
#                       "didn't want to eat it). \\n\\nAfter that we decided "
#                       'against dessert and left.  I probably will not return.',
#                       'I went there today! The cut was terrible! I have an '
#                       'awful experience. They lady that cut my hair was nice '
#                       'but she wanted to leave early so she made a disaster in '
#                       'my head!',
#                       'As a chinese american college student from NYC who got '
#                       'stuck in Pittsburgh with its useless public '
#                       'transportation (circa 1998), I desperately missed '
#                       'home-style Chinese food for the better part of my first '
#                       'two years here. Things turned around for me once I got '
#                       'a car (or made friends with cars), but I was seriously '
#                       'hurting for a while.\\n\\nTasty was one of the places '
#                       'we found. Back in the day, it was owned and ran by a '
#                       'typical restaurant-owning Chinese family. They had the '
#                       'works - pushy lao ban niang (boss lady), chef slash '
#                       'dad, and, during school off-hours, junior high school '
#                       'daughter manning the cashier. If they were in NYC, '
#                       "they'd only be missing an ami.... a bus boy. The food "
#                       'was pretty good, and if you order in Chinese, the lao '
#                       'ban niang hooked you up with extras because \\""your '
#                       'parents teach you good to talk Chineees\\"". \\n\\nI\'m '
#                       'pretty sure Tasty is under new ownership now. The food '
#                       "isn't as good as it was, but the restaurant still gives "
#                       "off the home-style look and feel. It's a small "
#                       'restaurant with enough seating for about 25-30 patrons. '
#                       'Cheap tables, cheap seats; after all, restaurant extras '
#                       'are just a waste of money. The customers should come '
#                       'back for the food, this *is* a restaurant.\\n\\nThe new '
#                       'waitress is not friendly, but she gets the job done. '
#                       "The food is still good - so if you're craving a home "
#                       "cooked meal, you'll be somewhat satisfied here. Don't "
#                       "expect grandma's cooking, though. Order the vegetables, "
#                       'the mapo tofu is good, beef/chicken chow fun, etc. They '
#                       "have a lot of other staple items on the menu too. Don't "
#                       'get the salted pork chops - save that craving for '
#                       'Orient Kitchen. Try things, and share your '
#                       "thoughts.\\n\\nTasty - it's more than your neighborhood "
#                       'take out joint.\\n\\n- written by a former junior high '
#                       'school daughter cashier',
#                       'This shelter is fantastic and has generally very good, '
#                       'friendly people on staff.  The cats and dogs appear to '
#                       'be treated at least as well as one might '
#                       'expect.\\n\\nWhen I adopted one of my cats at this '
#                       'establishment, I had to return the next day to have her '
#                       'spayed.  They did it for free, which was great, but the '
#                       "reason they don't get five stars is that the desk clerk "
#                       'completely forgot about my cat and me, and she left us '
#                       'waiting as she chatted on her cell phone with a friend: '
#                       'she only remembered about us as she was walking out for '
#                       'a smoke and saw us sitting in the lobby.',
#                       'Our cat recently came down with some health issues that '
#                       'we could not afford to address. He was in pain and we '
#                       'decided the humane thing was to put him to sleep. We '
#                       'went to the ARL and asked the receptionist there if we '
#                       'had any other options available to us. \\""Well '
#                       'basically the only thing you can do is sign him over '
#                       'for euthanasia\\"" she said in the most uncaring, '
#                       'apathetic voice possible. We were heartbroken of '
#                       'course. \\""Go wait by that door and someone will meet '
#                       'you.\\"" After a few minutes another woman came out and '
#                       'took the carrier. \\""I\'ll bring your carrier back out '
#                       'in a minute.\\"" We said no, that\'s okay, keep the '
#                       'carrier. She said okay and took our cat to the back. '
#                       'And that was it. No kind words, no sympathetic '
#                       'gestures, no \\""Would you like a moment before I take '
#                       'him?\\"" No \\""I\'m sorry.\\"" Nothing. For us this '
#                       'was one of the worst days of our lives but nobody at '
#                       'the ARL seemed to care, or at least have been trained '
#                       'to pretend to care, one bit. \\n\\nThey get a couple '
#                       'stars for offering a necessary service. But other than '
#                       'that, this place will only be associated with making a '
#                       'terrible day that much worse with their lack of caring '
#                       'or empathy.',
#                       'Yes! Awesome soy cap, scone, and atmosphere. Nice place '
#                       'to hang out & read, and free WiFi with no login '
#                       'procedure.',
#                       'The people who work here are very rude. I have gone '
#                       'back a few times thinking it may have just been the '
#                       'person working that day was just a rude person, but no '
#                       'it happen every time. I am not a young hip person and '
#                       'felt very out of place there. It is like you are '
#                       "walking into someone's house and bothering them. The "
#                       'people working behind the counter act like you are '
#                       'interfering with there conversation. Plus it is very '
#                       'dirty. Perhaps the people working there should try '
#                       'cleaning the place instead of talking to each other. I '
#                       'will not go back again.',
#                       "I've been here quite a few times, and I always try to "
#                       'like it cause theres a lack of good sports bars near '
#                       'Pitt. They have a ton of nice HDTVs.\\n\\nEverytime I '
#                       'go, there is always a weird taste to one (or more) of '
#                       'the beers that I get. I was just there for the '
#                       'Pitt/Oakland game and got a Redhook. I drink this beer '
#                       'regularly, and something was wrong with the beer. Its '
#                       'definitely hard to describe, but something is always '
#                       'off (others in my party notice it too).\\n\\nThe food '
#                       'is hit or miss. I got the French onion soup last time. '
#                       'It was good. Nothing ground breaking, but solid soup. '
#                       "I've had the pork nachos and they were blah.",
#                       'The location is convenient but I was not a fan of the '
#                       'food. I had shrimp and Chinese veggies and crab '
#                       'Rangoon. They cut the veggies way too big and the sauce '
#                       "was bland. I won't go back for food but the crab "
#                       "Rangoon was ok. They didn't give any sauce. You have to "
#                       'ask for it. That sucks.']})
# epoch 1, loss=0.005904789082705975:   1%|          | 159/14000 [00:01<02:26, 94.42it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\HEEGYU~1\AppData\Local\Temp/ipykernel_34504/3609282671.py in <module>
# ----> 1 trainer.run()
#
# C:\Users\HEEGYU~1\AppData\Local\Temp/ipykernel_34504/3025075056.py in run(self)
#      57
#      58         for e in range(self.config.num_epochs):
# ---> 59             self.run_train_epoch(e)
#      60             self.evaluate()
#      61
#
# C:\Users\HEEGYU~1\AppData\Local\Temp/ipykernel_34504/3025075056.py in run_train_epoch(self, epoch)
#      67         desc = tqdm(train_loader, desc=f"epoch {epoch}")
#      68         for batch in desc:
# ---> 69             loss = self.train_step(batch)
#      70             loss.backward()
#      71             losses.append(loss.item())
#
# C:\Users\HEEGYU~1\AppData\Local\Temp/ipykernel_34504/3025075056.py in train_step(self, batch)
#      83
#      84         with torch.no_grad():
# ---> 85             latent = self.vae.encode(texts)
#      86         latent_pred = self.style_transfer(latent, labels)
#      87
#
# d:\Anaconda3\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# c:\Users\heegyukim\Desktop\project\latent-diffusion-lm\coop\vae.py in encode(self, reviews, device)
#      75             self.to(self.device)
#      76         src = self.src_tokenizer(reviews)
# ---> 77         return self.model(src).q.loc
#      78
#      79     @torch.no_grad()
#
# d:\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\heegyukim\Desktop\project\latent-diffusion-lm\coop\models\bimeanvae.py in forward(self, src, tgt, do_generate, num_beams, **kwargs)
#      73         input_length = input_mask.sum(dim=1).cpu().tolist()
#      74         packed_embed = nn.utils.rnn.pack_padded_sequence(embed, input_length, batch_first=True, enforce_sorted=False)
# ---> 75         encoded = self.encoder(packed_embed)[0]
#      76         encoded = nn.utils.rnn.pad_packed_sequence(encoded, batch_first=True)[0]
#      77         encoded = masked_mean(encoded, input_mask.unsqueeze(-1), dim=1)
#
# d:\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# d:\Anaconda3\lib\site-packages\torch\nn\modules\rnn.py in forward(self, input, hx)
#     762                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     763         else:
# --> 764             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     765                               self.num_layers, self.dropout, self.training, self.bidirectional)
#     766         output = result[0]
#
# KeyboardInterrupt:

# %%
@torch.no_grad()
def transfer_style(vae: VAE, st_model: StyleTransferModel, text: str, style: int, device: str = "cuda:0"):
    vae.eval().to(device)
    st_model.eval().to(device)

    latent = vae.encode([text])
    style = torch.LongTensor([style]).to(device)
    latent = st_model(latent, style)

    prediction = vae.generate(latent)
    return prediction


text = "i love this restaurant. foods and mood are best."
transfer_style(
    trainer.vae,
    trainer.style_transfer,
    text,
    0
)
# Out:
# ['i love this restaurant. foods are good and service is great.']
